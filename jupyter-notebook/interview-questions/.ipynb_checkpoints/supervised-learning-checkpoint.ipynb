# %%
# 🎯 Round 1: Basics (warm-up)

# %%
# 1. What is supervised learning?

# Supervised learning is a type of machine learning where the model is trained on labeled data, meaning both input features and corresponding output labels are available. The goal is to learn a mapping from input to output.

# %%
# 2. What is the difference between classification and regression?

# Classification predicts discrete categories, while regression predicts continuous numerical values.

# %%
# 3. Give 2 real-world examples of classification problems.

# Pass/Fail
# Spam/Not Spam
# Disease detection (optional add)

# %%
# 4. Give 2 real-world examples of regression problems.

# House price prediction
# CGPA prediction (good)
# Salary prediction (optional add)

# %%
# 🎯 Round 2: Core Concepts
# What is a feature and what is a target variable?
# What is training data and testing data? Why do we split?
# What is overfitting?
# What is underfitting?
# How can you detect overfitting?

# %%
# 🎯 Round 3: Algorithms
# How does KNN (K-Nearest Neighbors) work in simple words?
# What happens if K is too small?
# What happens if K is too large?
# What is the difference between Linear Regression and Logistic Regression?

# %%
# 🎯 Round 4: Evaluation Metrics
# For classification, what is accuracy?
# When is accuracy NOT a good metric?
# What is precision and recall?
# For regression, name 2 evaluation metrics.

# %%
# 🎯 Round 5: Practical / Coding Thinking
# Why do we use GridSearchCV?
# What is cross-validation?
# What is the difference between fit() and predict()?
# What is data preprocessing? Give examples.

# %%
# 🔥 Bonus (Interview Level)
# What is bias vs variance tradeoff?
# Why do we normalize/scale data in KNN?
# What happens if your dataset has missing values?
# Explain a full ML pipeline in 5 steps.
